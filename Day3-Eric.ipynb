# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.2f}'.format

# %matplotlib inline

# %%
def get_mta_data(weeks):
    url = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt'
    df_list = []
    for week in weeks:
        df_list.append(pd.read_csv(url.format(week)))
    return pd.concat(df_list)

# %%
mta_df = get_mta_data([170506, 170513, 170520, 170527])
#mta_df = get_mta_data([170506])

# %%
mta_df.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  20:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/30/2017  00:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/30/2017  04:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/30/2017  08:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/30/2017  12:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6157740
# 1  REGULAR  6157777
# 2  REGULAR  6157810
# 3  REGULAR  6157963
# 4  REGULAR  6158212
# 5  REGULAR  6158521
# 6  REGULAR  6158637
# 7  REGULAR  6158654
# 8  REGULAR  6158661
# 9  REGULAR  6158703
#
#    EXITS
# 0                                            2085315
# 1                                            2085319
# 2                                            2085353
# 3                                            2085453
# 4                                            2085529
# 5                                            2085589
# 6                                            2085612
# 7                                            2085617
# 8                                            2085641
# 9                                            2085730

# %%
mta_df.groupby(['LINENAME', 'STATION']).size()
# Out:
# LINENAME  STATION
# 1         103 ST             1008
#           116 ST-COLUMBIA    1008
#           125 ST              855
#           137 ST CITY COL    1685
#           145 ST             1176
#           14TH STREET        1759
#           157 ST             1360
#           18 ST              1344
#           181 ST              840
#           191 ST              676
#           207 ST             1002
#           215 ST              672
#           23 ST              1172
#           231 ST             1689
#           238 ST              504
#           28 ST              1846
#           50 ST              3007
#           66 ST-LINCOLN      3862
#           79 ST              1520
#           86 ST              2345
#           9TH STREET          780
#           CANAL ST           1006
#           CATHEDRAL PKWY     1175
#           CHRISTOPHER ST     1638
#           CITY / BUS         3640
#           DYCKMAN ST         1008
#           EXCHANGE PLACE     4144
#           FRANKLIN ST        1350
#           GROVE STREET       3192
#           HARRISON           2031
#                              ...
# NQW       ASTORIA BLVD       1183
#           ASTORIA DITMARS    1335
#           BROADWAY           1005
# NRW       23 ST              2343
#           28 ST              1508
#           59 ST              1612
#           8 ST-NYU           2011
#           CITY HALL          1503
#           PRINCE ST          1685
#           RECTOR ST          1847
# Q         72 ST-2 AVE        2854
#           86 ST-2 AVE        2511
#           96 ST-2 AVE        2687
#           OCEAN PKWY         1174
# R         25 ST              1020
#           45 ST               712
#           77 ST               716
#           86 ST              1531
#           BAY RIDGE AV         90
#           BAY RIDGE-95 ST    1524
#           JAY ST-METROTEC    1512
#           PROSPECT AV        1017
#           RIT-MANHATTAN       668
#           RIT-ROOSEVELT      1037
#           UNION ST           1023
# R1W       WHITEHALL S-FRY    2534
# R2345     BOROUGH HALL        890
# RNW       CORTLANDT ST       5022
# S         PARK PLACE          839
# S2345     BOTANIC GARDEN      672
# dtype: int64

# %%
def get_entries(mta_df):
    d = {}
    turnstile_d = {}
    for row in mta_df.itertuples():
        C_A, unit, scp, station, linename = row[1], row[2], row[3], row[4], row[5]
        date = row[7]
        entries = row[10]
        k = (C_A, unit, scp, station, linename, date)
        if k not in d:
            d[k] = [entries]
        else:
            d[k].append(entries)
    
    for key, value in d.items():
        #if len(value) >= 2:
        #    entries_diffs = sorted([abs(value[i+1]-value[i]) for i in range(len(value)-1)])
        #    if entries_diffs[-1] > 10000000:
        #        entries_diffs = entries_diffs[:-1]
        #    entry = sum(entries_diffs)
        #    turnstile_d[key] = [entry]
        entry = abs(max(value) - min(value))
        turnstile_d[key] = [entry]
    return turnstile_d

# %%
d = get_entries(mta_df)

# %%
dict_df = pd.DataFrame.from_dict(d, orient='index')
dict_df.rename(columns = {0:'Entries'}, inplace=True)
dict_df.head(10)
# Out:
#                                                     Entries
# (A002, R051, 02-00-00, 59 ST, NQR456W, 04/29/2017)      781
# (A002, R051, 02-00-00, 59 ST, NQR456W, 04/30/2017)      378
# (A002, R051, 02-00-00, 59 ST, NQR456W, 05/01/2017)     1267
# (A002, R051, 02-00-00, 59 ST, NQR456W, 05/02/2017)     1322
# (A002, R051, 02-00-00, 59 ST, NQR456W, 05/03/2017)     1193
# (A002, R051, 02-00-00, 59 ST, NQR456W, 05/04/2017)     1348
# (A002, R051, 02-00-00, 59 ST, NQR456W, 05/05/2017)     1072
# (A002, R051, 02-00-01, 59 ST, NQR456W, 04/29/2017)      646
# (A002, R051, 02-00-01, 59 ST, NQR456W, 04/30/2017)      538
# (A002, R051, 02-00-01, 59 ST, NQR456W, 05/01/2017)      976

# %%
turnstile_df = pd.DataFrame(columns=[])

# %%
turnstile_df['C/A'] = [row[0][0] for row in dict_df.itertuples()]
turnstile_df['Unit'] = [row[0][1] for row in dict_df.itertuples()]
turnstile_df['SCP'] = [row[0][2] for row in dict_df.itertuples()]
turnstile_df['Station'] = [row[0][3] for row in dict_df.itertuples()]
turnstile_df['Linename'] = [row[0][4] for row in dict_df.itertuples()]
turnstile_df['Date'] = [row[0][5] for row in dict_df.itertuples()]
turnstile_df['Entries'] = [row[1] for row in dict_df.itertuples()]

# %%
turnstile_df.head(10)
# Out:
#     C/A  Unit       SCP Station Linename        Date  Entries
# 0  A002  R051  02-00-00   59 ST  NQR456W  04/29/2017      781
# 1  A002  R051  02-00-00   59 ST  NQR456W  04/30/2017      378
# 2  A002  R051  02-00-00   59 ST  NQR456W  05/01/2017     1267
# 3  A002  R051  02-00-00   59 ST  NQR456W  05/02/2017     1322
# 4  A002  R051  02-00-00   59 ST  NQR456W  05/03/2017     1193
# 5  A002  R051  02-00-00   59 ST  NQR456W  05/04/2017     1348
# 6  A002  R051  02-00-00   59 ST  NQR456W  05/05/2017     1072
# 7  A002  R051  02-00-01   59 ST  NQR456W  04/29/2017      646
# 8  A002  R051  02-00-01   59 ST  NQR456W  04/30/2017      538
# 9  A002  R051  02-00-01   59 ST  NQR456W  05/01/2017      976

# %%
avg_entries_df = turnstile_df.groupby(['C/A', 'Linename', 'Station']).mean().sort_values('Entries', ascending=False)[:10]
avg_entries_df
# Out:
#                                   Entries
# C/A   Linename Station
# R241A 4567S    GRD CNTRL-42 ST 3490816.39
# R169  123      96 ST           1353530.93
# N138  A        111 ST           746277.55
# A054  NRW      RECTOR ST        600937.36
# R160A 1        66 ST-LINCOLN    597452.98
# R602  2345R    BOROUGH HALL     503000.95
# N223  BD       BEDFORD PK BLVD  272892.29
# R287  4        BURNSIDE AV      222068.87
# H037  L        SUTTER AV        213076.34
# B022  BQ       AVENUE M         177440.37

# %%
plt.plot(avg_entries_df['Station'], avg_entries_df['Entries'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/eric/anaconda/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'Station'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-69e263aad385> in <module>()
# ----> 1 plt.plot(avg_entries_df['Station'], avg_entries_df['Entries'])
#
# /Users/eric/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /Users/eric/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /Users/eric/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /Users/eric/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/eric/anaconda/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'Station'

# %%
# Out:
#     C/A  Unit       SCP Station Linename        Date  Entries
# 0  A002  R051  02-00-00   59 ST  NQR456W  04/29/2017      781
# 1  A002  R051  02-00-00   59 ST  NQR456W  04/30/2017      378
# 2  A002  R051  02-00-00   59 ST  NQR456W  05/01/2017     1267
# 3  A002  R051  02-00-00   59 ST  NQR456W  05/02/2017     1322
# 4  A002  R051  02-00-00   59 ST  NQR456W  05/03/2017     1193

# %%
def delete_outliers(df, iters=5):
    '''
    finds the max values in a dataframe grouped by columns
    input a data frame
    iters = number of outliers to delete
    '''
    for i in range(iters):
        to_delete_rows = df.loc[df.groupby(["Station","Linename"])['Entries'].idxmax()]
        to_delete_indices = list(to_delete_rows.index.values)
        df.drop(to_delete_indices, inplace=True)
    return df

# %%
no_outliers_turnstile_df = delete_outliers(turnstile_df, iters=5)

# %%
no_outliers_turnstile_df['Entries'].max()
# Out:
# 8170

# %%
no_outliers_turnstile_df.groupby(['Linename', 'Station']).sum().sort_values(by='Entries',ascending=False)
# Out:
#                               Entries
# Linename     Station
# 4567S        GRD CNTRL-42 ST  3197912
# BDFMNQRW     34 ST-HERALD SQ  2648443
# ACENQRS1237W 42 ST-PORT AUTH  1963100
# ACE          34 ST-PENN STA   1721122
# LNQR456W     14 ST-UNION SQ   1600890
# 7            FLUSHING-MAIN    1353159
# 2345ACJZ     FULTON ST        1344909
# 1237ACENQRSW TIMES SQ-42 ST   1313401
# ABCD1        59 ST COLUMBUS   1230768
# 123ACE       34 ST-PENN STA   1230277
# 1            PATH NEW WTC     1194599
# BDFM         47-50 STS ROCK   1181045
# JNQRZ6W      CANAL ST         1129831
# EFMR7        JKSN HT-ROOSVLT  1102635
# 456          86 ST            1010343
# 456NQRW      59 ST             920405
# 123          72 ST             920358
#              96 ST             909211
# ACF          JAY ST-METROTEC   884767
# EM6          LEXINGTON AV/53   882252
# EJZ          JAMAICA CENTER    881784
# ABCDEFM      W 4 ST-WASH SQ    879958
# BDFM7        42 ST-BRYANT PK   802724
# 2345R        BOROUGH HALL      721965
# NQRW         57 ST-7 AV        714591
# 34           CROWN HTS-UTICA   713147
# 123          34 ST-PENN STA    700118
# 456LNQRW     14 ST-UNION SQ    676005
# ACE23        CHAMBERS ST       666089
# ACBD         125 ST            660823
# ...                               ...
# S            PARK PLACE         40466
# L            ATLANTIC AV        39280
# A            104 ST             37874
# 1            NEWARK HM HE       35802
# N            FT HAMILTON PKY    35529
# S2345        BOTANIC GARDEN     35340
# G            21 ST              35003
# F            NEPTUNE AV         34376
#              AVENUE I           32763
# A            AQUEDUCT RACETR    31503
# N            AVENUE U           30675
#              KINGS HWY          29457
# J            CYPRESS HILLS      29307
# JZ           104 ST             24321
# N            86 ST              23532
# F            BAY PKWY           23272
# 6            E 143/ST MARY'S    21253
# A            BEACH 36 ST        21245
# N            20 AV              20812
# A            AQUEDUCT N.COND    20621
# 1            TOMPKINSVILLE      18498
# AS           BEACH 90 ST        18445
# JZ           121 ST             16034
# A            BEACH 44 ST        14983
# AS           ROCKAWAY PARK B    14262
#              BEACH 98 ST        11021
#              BROAD CHANNEL       5855
#              BEACH 105 ST        5448
# 6            ORCHARD BEACH         15
# R            BAY RIDGE AV           0
#
# [475 rows x 1 columns]
